# %%
import pickle

# %%
loaded_model=pickle.load(open("FinalizedMultipleLinearRegression.sav",'rb'))
result=loaded_model.predict([[12323,345,3354,1,0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[52726.86605282]])
