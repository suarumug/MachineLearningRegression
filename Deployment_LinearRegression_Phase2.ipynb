# %%
# import pickle libraries again for pickle function to work in this page
import pickle

# %%
# just copying the loaded model steps here in deployemnt phase to load and display teh result to user 
loaded_model=pickle.load(open("finalized_model_linear.sav","rb"))
result=loaded_model.predict([[0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[26777.3913412]])
